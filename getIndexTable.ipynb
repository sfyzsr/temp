# %%
import pandas as pd

# %%
indexs = pd.read_csv('index.txt',  delim_whitespace=True )
indexs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4038 entries, 0 to 4037
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   指数代码    4038 non-null   object
#  1   指数简称    4038 non-null   object
#  2   指数全称    4038 non-null   object
#  3   发布日期    4038 non-null   object
#  4   退市日期    4038 non-null   object
#  5   指数行情    2670 non-null   object
#  6   指数权重    2552 non-null   object
#  7   指数成分    2879 non-null   object
# dtypes: object(8)
# memory usage: 252.5+ KB

# %%
indexs = indexs.drop(indexs[indexs['发布日期'] == '0000-00-00'].index)

# %%
indexs[indexs['发布日期'] == '0000-00-00']
indexs
# Out:
#              指数代码   指数简称          指数全称        发布日期        退市日期 指数行情 指数权重 指数成分
# 0     000001.XSHG   上证指数   上海证券交易所综合指数  1991-07-15  0000-00-00    有    有    有
# 1     000002.XSHG   A股指数   上海证券交易所Ａ股指数  1992-02-21  0000-00-00    有    有    有
# 2     000003.XSHG   B股指数   上海证券交易所Ｂ股指数  1992-08-17  0000-00-00    有    有    有
# 3     000004.XSHG   工业指数   上海证券交易所工业指数  1993-05-03  0000-00-00    有    有    有
# 4     000005.XSHG   商业指数   上海证券交易所商业指数  1993-05-03  0000-00-00    有    有    有
# ...           ...    ...           ...         ...         ...  ...  ...  ...
# 4033  H30072.XSHG  贵金CFI   中证贵金属期货成份指数   2013/2/21  0000-00-00    有  NaN  NaN
# 4034  H30224.XSHG  粮油CFI    中证粮油期货成份指数   2013/8/15  0000-00-00    有  NaN  NaN
# 4035  H30225.XSHG  有色CFI  中证有色金属期货成份指数   2013/8/15  0000-00-00    有  NaN  NaN
# 4036  H30226.XSHG  化工CFI  中证化工材料期货成份指数   2013/8/15  0000-00-00    有  NaN  NaN
# 4037  H30227.XSHG  工业CFI   中证工业品期货成份指数   2013/8/15  0000-00-00    有  NaN  NaN
#
# [4035 rows x 8 columns]

# %%
indexs['发布日期'] = pd.to_datetime(indexs['发布日期'])

# %%
crop = indexs[indexs['发布日期']<'2000-01-02']
crop
# Out:
#              指数代码      指数简称           指数全称       发布日期        退市日期 指数行情 指数权重  \
# 0     000001.XSHG      上证指数    上海证券交易所综合指数 1991-07-15  0000-00-00    有    有
# 1     000002.XSHG      A股指数    上海证券交易所Ａ股指数 1992-02-21  0000-00-00    有    有
# 2     000003.XSHG      B股指数    上海证券交易所Ｂ股指数 1992-08-17  0000-00-00    有    有
# 3     000004.XSHG      工业指数    上海证券交易所工业指数 1993-05-03  0000-00-00    有    有
# 4     000005.XSHG      商业指数    上海证券交易所商业指数 1993-05-03  0000-00-00    有    有
# 5     000006.XSHG      地产指数    上海证券交易所地产指数 1993-05-03  0000-00-00    有    有
# 6     000007.XSHG      公用指数    上海证券交易所公用指数 1993-05-03  0000-00-00    有    有
# 7     000008.XSHG      综合指数  上海证券交易所综合行业指数 1993-05-03  0000-00-00    有    有
# 315   399001.XSHE      深证成指         深证成份指数 1995-01-23  0000-00-00    有    有
# 316   399002.XSHE      成份Ａ指      深证成份全收益指数 1995-01-23  0000-00-00    有    有
# 317   399003.XSHE      成份B指       深证成份B股指数 1995-01-23  0000-00-00    有  NaN
# ...

# %%
crop.to_csv('crop_indexs.csv', index=False)
